# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
from zoneinfo import ZoneInfo
import numpy as np

tz = ZoneInfo('America/New_York')
utc = ZoneInfo('UTC')

# %%
df = pd.read_parquet('../data/test/NQ_2024-09-06_2025-09-13.parquet')
dfs = df.loc['2025-09-02T15:55':'2025-09-12T18:05']
df

# %%
dfs = df.head(5)
dfs.reset_index(drop=True, inplace=True)
dfs.reindex(range(0,7), fill_value=0)
